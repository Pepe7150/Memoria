# %% [markdown]
# # Centro de Operaciones – Memoria de Título
#
# Este cuaderno será el repositorio maestro del proyecto. Aquí se documentará el estado de avance, decisiones de diseño, revisión bibliográfica, resultados y planificación.

# %% [markdown]
# # Objetivos
#
# ## Objetivo general
# Continuar el trabajo de Systems Engineering mediante el desarrollo progresivo de una plataforma GNC.
#
# ## Objetivos específicos
# - Implementar un modelo dinámico publicado.
# - Parametrizar el modelo.
# - Diseñar el controlador.
# - Validar mediante simulación.
# - Implementar HIL.
# - Integrar y preparar demostrador.

# %% [markdown]
# # Hoja de ruta
#
# | Etapa | Estado |
# |---|:---:|
# | Systems Engineering | ✅ |
# | Modelo dinámico | ✅ |
# | Parametrización | 🟡 |
# | Controlador | 🟡 |
# | Incertidumbres | 🔴 |
# | MATLAB | 🟡 |
# | HIL | 🔴 |
# | Prototipo | 🟡 |
# | Integración | 🟡 |
# | Banco de ensayos | 🟡 |
# | Ensayos de vuelo | 🟡 |

# %% [markdown]
# # Cronograma
#
# > Agregar posteriormente un Gantt o tabla de planificación.

# %% [markdown]
# # Revisión bibliográfica
#
# ## Modelo dinámico
# - [ ]
#
# ## Control
# - [ ]
#
# ## Robustez
# - [ ]
#
# ## HIL
# - [ ]
#
#
# ## Resumen de papers
#
# | Paper | Aporte | Implementado |
# |-------|---------|--------------|
# | | | |

# %% [markdown]
# # Modelo dinámico
#
# - Modelo seleccionado:
# - Referencia:
# - Hipótesis:
# - Estados:
# - Entradas:
# - Salidas:
# - Validación del modelo.

# %% [markdown]
# # Parametrización
#
# ## Geometría
# ## Masa
# ## Centro de gravedad
# ## Momentos de inercia
# ## Propulsión
# ## Aerodinámica

# %% [markdown]
# # Controlador
#
# - Arquitecturas candidatas
#     - PID
#     - LQR
#     - MPC
#     - Otro
#
# ## Decisión final

# %% [markdown]
# # Robustez e incertidumbres
#
# - Variación de masa
# - Variación del CG
# - Variación del empuje
# - Variación de coeficientes aerodinámicos
# - Ruido IMU
# - Saturaciones
# - Monte Carlo

# %% [markdown]
# # MATLAB / Simulink
#
# ## Estructura del modelo
# ## Resultados
# ## Validaciones

# %% [markdown]
# # Hardware in the Loop
#
# ## Hardware candidato
# | Plataforma | Precio | Observaciones |
# |---|---:|---|
# | STM32 | | |
# | Pixhawk | | |
# | Raspberry Pi | | |

# %% [markdown]
# # Prototipo estructural
#
# ## CAD
# ## Material
# ## Impresión 3D
# ## Distribución de masas

# %% [markdown]
# # Integración
#
# Checklist:
# - [ ] IMU
# - [ ] Computador
# - [ ] Actuadores
# - [ ] Alimentación
# - [ ] Comunicaciones

# %% [markdown]
# # Banco de ensayos
#
# ## Objetivos
# ## Instrumentación
# ## Variables medidas
# ## Resultados

# %% [markdown]
# # Ensayos de vuelo
#
# ## Plan de pruebas
# ## Seguridad
# ## Instrumentación
# ## Resultados

# %% [markdown]
# # Reuniones y bitácora
#
# Fecha | Tema | Acuerdos | Próximos pasos
# |---|---|---|---|

# %% [markdown]
# # Ideas futuras
#
# Anotar cualquier idea, paper, mejora o posible continuación de la línea de investigación.
